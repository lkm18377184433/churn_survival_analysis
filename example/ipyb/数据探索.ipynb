# %% [markdown]
# # 环境配置

# %%
import warnings

warnings.filterwarnings("ignore")

import seaborn as sns
from pandas import read_csv
from pandas import set_option
from scipy.stats import norm
import matplotlib.pyplot as plt
from toad.detector import detect

set_option("display.width", 10000)
set_option("display.max_rows", None)
set_option("display.max_columns", None)
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %matplotlib inline

# %% [markdown]
# # 加载数据

# %%
data = read_csv("../data/Telco-Customer-Churn.csv", encoding="utf-8")

# %% [markdown]
# ## 转换类型

# %%
data["TotalCharges"] = data["TotalCharges"].apply(lambda x: "0" if x == " " else x)
data["TotalCharges"] = data["TotalCharges"].astype(float)

# %% [markdown]
# # 数据探索

# %% [markdown]
# ## 查看数据

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0  7590-VHVEG  Female              0     Yes         No       1           No  No phone service             DSL             No          Yes               No          No          No              No  Month-to-month              Yes           Electronic check           29.85         29.85    No
# 1  5575-GNVDE    Male              0      No         No      34          Yes                No             DSL            Yes           No              Yes          No          No              No        One year               No               Mailed check           56.95       1889.50    No
# ...

# %% [markdown]
# ## 基本属性

# %%
detect(data).iloc[:, :4]
# Out:
#                      type  size missing  unique
# customerID         object  7043   0.00%    7043
# gender             object  7043   0.00%       2
# SeniorCitizen       int64  7043   0.00%       2
# Partner            object  7043   0.00%       2
# Dependents         object  7043   0.00%       2
# tenure              int64  7043   0.00%      73
# PhoneService       object  7043   0.00%       2
# MultipleLines      object  7043   0.00%       3
# InternetService    object  7043   0.00%       3
# OnlineSecurity     object  7043   0.00%       3
# OnlineBackup       object  7043   0.00%       3
# DeviceProtection   object  7043   0.00%       3
# TechSupport        object  7043   0.00%       3
# StreamingTV        object  7043   0.00%       3
# StreamingMovies    object  7043   0.00%       3
# Contract           object  7043   0.00%       3
# PaperlessBilling   object  7043   0.00%       2
# PaymentMethod      object  7043   0.00%       4
# MonthlyCharges    float64  7043   0.00%    1585
# ...

# %% [markdown]
# ## 分离数据

# %%
nums = ["MonthlyCharges", "TotalCharges"]
objs = ["SeniorCitizen", 'gender', 'Partner', 'Dependents', 'PhoneService', 
        'MultipleLines', 'InternetService', 'OnlineSecurity', 
        'OnlineBackup', 'DeviceProtection', 'TechSupport', 
        'StreamingTV', 'StreamingMovies', 'Contract', 
        'PaperlessBilling', 'PaymentMethod']
num_data = data[nums].join(data[["tenure", "Churn"]])
obj_data = data[objs].join(data[["tenure", "Churn"]])

# %% [markdown]
# # 特征探索

# %% [markdown]
# ## 数值型特征

# %% [markdown]
# 偏度（Skewness）
# 用来描述数据分布的对称性，正态分布的偏度为0。计算数据样本的偏度，当偏度<0时，称为负偏，数据出现左侧长尾；当偏度>0时，称为正偏，数据出现右侧长尾；当偏度为0时，表示数据相对均匀的分布在平均值两侧，不一定是绝对的对称分布，此时要与正态分布偏度为0的情况进行区分。
# 当偏度绝对值过大时，长尾的一侧出现极端值的可能性较高。
# 峰度(Kurtosis)
# 用来描述数据分布陡峭或是平滑的情况。正态分布的峰度为3，峰度越大，代表分布越陡峭，尾部越厚；峰度越小，分布越平滑。很多情况下，为方便计算，将峰度值－3，因此正态分布的峰度变为0，方便比较。
# 在方差相同的情况下，峰度越大，存在极端值的可能性越高。

# %% [markdown]
# ### MonthlyCharges（月费用）

# %%
plt.figure(figsize=(14, 6), dpi=300)

# 绘制分布图
plt.subplot(1, 2, 1)
sns.distplot(num_data["MonthlyCharges"], fit=norm)
for i, j, z in zip([num_data["MonthlyCharges"].skew(), num_data["MonthlyCharges"].kurt()], [0.02, 0.022], ["偏度", "峰度"]):
    plt.text(50, j, "{}({:4f})".format(z, i))

# 绘制箱线图
plt.subplot(1, 2, 2)
sns.boxplot(x="MonthlyCharges", data=num_data)

# %% [markdown]
# ### TotalCharges（总费用）

# %%
plt.figure(figsize=(14, 6), dpi=300)

# 绘制分布图
plt.subplot(1, 2, 1)
sns.distplot(num_data["TotalCharges"], fit=norm)
for i, j, z in zip([num_data["TotalCharges"].skew(), num_data["TotalCharges"].kurt()], [0.0004, 0.00045], ["偏度", "峰度"]):
    plt.text(4000, j, "{}({:4f})".format(z, i))

# 绘制箱线图
plt.subplot(1, 2, 2)
sns.boxplot(x="TotalCharges", data=num_data)

# %% [markdown]
# ## 字符型特征

# %% [markdown]
# ### SeniorCitizen（是否是老年人）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('SeniorCitizen',hue='Churn',data=obj_data)

# %% [markdown]
# ### gender（性别）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('gender',hue='Churn',data=obj_data)

# %% [markdown]
# ### Partner（是否单身）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('Partner',hue='Churn',data=obj_data)

# %% [markdown]
# ### Dependents（经济是否独立）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('Dependents',hue='Churn',data=obj_data)

# %% [markdown]
# ### PhoneService（电话业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('PhoneService',hue='Churn',data=obj_data)

# %% [markdown]
# ### MultipleLines（多线业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('MultipleLines',hue='Churn',data=obj_data)

# %% [markdown]
# ### InternetService（网络服务业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('InternetService',hue='Churn',data=obj_data)

# %% [markdown]
# ### OnlineSecurity（网络安全业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('OnlineSecurity',hue='Churn',data=obj_data)

# %% [markdown]
# ### OnlineBackup（网络备份业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('OnlineBackup',hue='Churn',data=obj_data)

# %% [markdown]
# ### DeviceProtection（设备保护业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('DeviceProtection',hue='Churn',data=obj_data)

# %% [markdown]
# ### TechSupport（技术支持业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('TechSupport',hue='Churn',data=obj_data)

# %% [markdown]
# ### StreamingTV（网络电视业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('StreamingTV',hue='Churn',data=obj_data)

# %% [markdown]
# ### StreamingMovies（网络电影业务）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('StreamingMovies',hue='Churn',data=obj_data)

# %% [markdown]
# ### Contract（合同方式）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('Contract',hue='Churn',data=obj_data)

# %% [markdown]
# ### PaperlessBilling（电子账单）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('PaperlessBilling',hue='Churn',data=obj_data)

# %% [markdown]
# ### PaymentMethod（支付方式）

# %%
plt.figure(figsize=(8, 6), dpi=300)
sns.countplot('PaymentMethod',hue='Churn',data=obj_data)
